# %%
import os
import open3d as o3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Poisson Surface Reconstruction

# %%
import os
import open3d as o3d

def set_mesh_color(mesh, color):
    if not mesh.has_vertices():
        print("Mesh has no vertices to color.")
        return
    colors = [color for _ in range(len(mesh.vertices))]
    mesh.vertex_colors = o3d.utility.Vector3dVector(colors)

def process_point_cloud(ply_file, output_mesh_file, color=(0.1, 0.1, 0.7)):
    # Load point cloud
    pcd = o3d.io.read_point_cloud(ply_file)
    
    # Downsample
    pcd = pcd.voxel_down_sample(voxel_size=0.02)
    
    # Noise removal
    pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
    
    # Estimate normals
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Surface reconstruction using Poisson method
    mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)
    
    # Check if the mesh has vertices
    if not mesh.has_vertices():
        print(f"No vertices found in the generated mesh for {ply_file}. Skipping.")
        return
    
    mesh.compute_vertex_normals()
    
    # Set the mesh color
    set_mesh_color(mesh, color)
    
    # Save the mesh
    o3d.io.write_triangle_mesh(output_mesh_file, mesh, write_vertex_normals=True, write_vertex_colors=True)
    
    print(f"Processed and saved: {output_mesh_file}")

def visualize_mesh(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()
    
    if not mesh.has_vertex_colors():
        print(f"Mesh {mesh_file} has no vertex colors. Visualizing without colors.")
    
    # Ensure the vertex colors are used in visualization
    o3d.visualization.draw_geometries([mesh], mesh_show_back_face=True)

# Function to compute properties of the mesh
def compute_properties(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()

    # Surface area
    surface_area = mesh.get_surface_area()

    return surface_area

# Directory paths
input_ply_dir = r"D:\ply_final\one"
output_mesh_dir = r"D:\poisson"

# Ensure output directory exists
os.makedirs(output_mesh_dir, exist_ok=True)

# Process each point cloud
for ply_file in os.listdir(input_ply_dir):
    if ply_file.endswith(".ply"):
        ply_file_path = os.path.join(input_ply_dir, ply_file)
        output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_mesh.obj"))
        
        process_point_cloud(ply_file_path, output_mesh_file, color=(0.4, 0.4, 0.4))  # Change color as needed
        #visualize_mesh(output_mesh_file)
        
        surface_area = compute_properties(output_mesh_file)
        print(f"Mesh {output_mesh_file}: Surface Area = {surface_area}")
# Out:
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_1_mesh.obj
# Mesh D:\poisson\point_cloud_1_mesh.obj: Surface Area = 516684.3033567388
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_10_mesh.obj
# Mesh D:\poisson\point_cloud_10_mesh.obj: Surface Area = 525370.4126904337
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_100_mesh.obj
# Mesh D:\poisson\point_cloud_100_mesh.obj: Surface Area = 528409.0270672933
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_101_mesh.obj
# Mesh D:\poisson\point_cloud_101_mesh.obj: Surface Area = 553215.7044541324
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_102_mesh.obj
# Mesh D:\poisson\point_cloud_102_mesh.obj: Surface Area = 500844.89462447824
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_103_mesh.obj
# Mesh D:\poisson\point_cloud_103_mesh.obj: Surface Area = 510587.26925332984
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_104_mesh.obj
# Mesh D:\poisson\point_cloud_104_mesh.obj: Surface Area = 550792.7719590433
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_105_mesh.obj
# Mesh D:\poisson\point_cloud_105_mesh.obj: Surface Area = 552071.4074822123
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_106_mesh.obj
# Mesh D:\poisson\point_cloud_106_mesh.obj: Surface Area = 565827.9413486894
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_107_mesh.obj
# Mesh D:\poisson\point_cloud_107_mesh.obj: Surface Area = 580029.0618561518
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_108_mesh.obj
# Mesh D:\poisson\point_cloud_108_mesh.obj: Surface Area = 558331.1374775994
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_109_mesh.obj
# Mesh D:\poisson\point_cloud_109_mesh.obj: Surface Area = 572933.7152149131
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_11_mesh.obj
# Mesh D:\poisson\point_cloud_11_mesh.obj: Surface Area = 515891.39521879173
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_110_mesh.obj
# Mesh D:\poisson\point_cloud_110_mesh.obj: Surface Area = 596628.268206568
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_111_mesh.obj
# Mesh D:\poisson\point_cloud_111_mesh.obj: Surface Area = 568898.6271566999
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_112_mesh.obj
# Mesh D:\poisson\point_cloud_112_mesh.obj: Surface Area = 558988.0934741299
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_113_mesh.obj
# Mesh D:\poisson\point_cloud_113_mesh.obj: Surface Area = 544561.4476057836
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_114_mesh.obj
# Mesh D:\poisson\point_cloud_114_mesh.obj: Surface Area = 547153.0257454355
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_115_mesh.obj
# Mesh D:\poisson\point_cloud_115_mesh.obj: Surface Area = 521381.7781819343
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_116_mesh.obj
# Mesh D:\poisson\point_cloud_116_mesh.obj: Surface Area = 533834.0569556202
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_117_mesh.obj
# Mesh D:\poisson\point_cloud_117_mesh.obj: Surface Area = 538241.5438099061
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_118_mesh.obj
# Mesh D:\poisson\point_cloud_118_mesh.obj: Surface Area = 559529.998916865
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_119_mesh.obj
# Mesh D:\poisson\point_cloud_119_mesh.obj: Surface Area = 580132.652436467
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_12_mesh.obj
# Mesh D:\poisson\point_cloud_12_mesh.obj: Surface Area = 528186.7976192513
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_120_mesh.obj
# Mesh D:\poisson\point_cloud_120_mesh.obj: Surface Area = 529416.9822265522
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_121_mesh.obj
# Mesh D:\poisson\point_cloud_121_mesh.obj: Surface Area = 578387.2259697985
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_122_mesh.obj
# Mesh D:\poisson\point_cloud_122_mesh.obj: Surface Area = 559320.3922101494
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_123_mesh.obj
# Mesh D:\poisson\point_cloud_123_mesh.obj: Surface Area = 548067.6619545844
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_124_mesh.obj
# Mesh D:\poisson\point_cloud_124_mesh.obj: Surface Area = 525580.6905131061
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_125_mesh.obj
# Mesh D:\poisson\point_cloud_125_mesh.obj: Surface Area = 548693.2439743561
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_126_mesh.obj
# Mesh D:\poisson\point_cloud_126_mesh.obj: Surface Area = 526471.8905614454
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_127_mesh.obj
# Mesh D:\poisson\point_cloud_127_mesh.obj: Surface Area = 517497.35505775665
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_128_mesh.obj
# Mesh D:\poisson\point_cloud_128_mesh.obj: Surface Area = 507420.07242707454
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_129_mesh.obj
# Mesh D:\poisson\point_cloud_129_mesh.obj: Surface Area = 511801.514014899
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_13_mesh.obj
# Mesh D:\poisson\point_cloud_13_mesh.obj: Surface Area = 525289.4888760262
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_130_mesh.obj
# Mesh D:\poisson\point_cloud_130_mesh.obj: Surface Area = 512989.2648600368
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_131_mesh.obj
# Mesh D:\poisson\point_cloud_131_mesh.obj: Surface Area = 513653.7817229083
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_132_mesh.obj
# Mesh D:\poisson\point_cloud_132_mesh.obj: Surface Area = 519521.8274009989
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_133_mesh.obj
# Mesh D:\poisson\point_cloud_133_mesh.obj: Surface Area = 520763.9485305689
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_134_mesh.obj
# Mesh D:\poisson\point_cloud_134_mesh.obj: Surface Area = 531870.0442826311
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_135_mesh.obj
# Mesh D:\poisson\point_cloud_135_mesh.obj: Surface Area = 538268.117737614
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_136_mesh.obj
# Mesh D:\poisson\point_cloud_136_mesh.obj: Surface Area = 535138.5563461501
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_137_mesh.obj
# Mesh D:\poisson\point_cloud_137_mesh.obj: Surface Area = 519387.6909301481
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_138_mesh.obj
# Mesh D:\poisson\point_cloud_138_mesh.obj: Surface Area = 504955.9397902986
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_139_mesh.obj
# Mesh D:\poisson\point_cloud_139_mesh.obj: Surface Area = 513860.6931423732
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_14_mesh.obj
# Mesh D:\poisson\point_cloud_14_mesh.obj: Surface Area = 662694.6061033369
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_140_mesh.obj
# Mesh D:\poisson\point_cloud_140_mesh.obj: Surface Area = 522508.9919965969
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_141_mesh.obj
# Mesh D:\poisson\point_cloud_141_mesh.obj: Surface Area = 523226.4367240178
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_142_mesh.obj
# Mesh D:\poisson\point_cloud_142_mesh.obj: Surface Area = 624835.9837709233
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_143_mesh.obj
# Mesh D:\poisson\point_cloud_143_mesh.obj: Surface Area = 796771.3968157129
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_144_mesh.obj
# Mesh D:\poisson\point_cloud_144_mesh.obj: Surface Area = 530851.2760973435
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_145_mesh.obj
# Mesh D:\poisson\point_cloud_145_mesh.obj: Surface Area = 519462.42218204285
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_146_mesh.obj
# Mesh D:\poisson\point_cloud_146_mesh.obj: Surface Area = 516067.7364170173
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_147_mesh.obj
# Mesh D:\poisson\point_cloud_147_mesh.obj: Surface Area = 571229.3233199553
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_148_mesh.obj
# Mesh D:\poisson\point_cloud_148_mesh.obj: Surface Area = 512196.26943652803
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_149_mesh.obj
# Mesh D:\poisson\point_cloud_149_mesh.obj: Surface Area = 513468.01877759857
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_15_mesh.obj
# Mesh D:\poisson\point_cloud_15_mesh.obj: Surface Area = 525193.0960816138
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_150_mesh.obj
# Mesh D:\poisson\point_cloud_150_mesh.obj: Surface Area = 523895.79865579057
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_151_mesh.obj
# Mesh D:\poisson\point_cloud_151_mesh.obj: Surface Area = 552237.0656145306
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_152_mesh.obj
# Mesh D:\poisson\point_cloud_152_mesh.obj: Surface Area = 520987.21579135617
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_153_mesh.obj
# Mesh D:\poisson\point_cloud_153_mesh.obj: Surface Area = 524606.9733533277
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_154_mesh.obj
# Mesh D:\poisson\point_cloud_154_mesh.obj: Surface Area = 540616.8532492189
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_155_mesh.obj
# Mesh D:\poisson\point_cloud_155_mesh.obj: Surface Area = 513465.39308808086
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_156_mesh.obj
# Mesh D:\poisson\point_cloud_156_mesh.obj: Surface Area = 522338.48650651635
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_157_mesh.obj
# Mesh D:\poisson\point_cloud_157_mesh.obj: Surface Area = 835440.9405981156
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_158_mesh.obj
# Mesh D:\poisson\point_cloud_158_mesh.obj: Surface Area = 530492.112302644
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_159_mesh.obj
# Mesh D:\poisson\point_cloud_159_mesh.obj: Surface Area = 574438.570846899
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_16_mesh.obj
# Mesh D:\poisson\point_cloud_16_mesh.obj: Surface Area = 518203.44897172874
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_160_mesh.obj
# Mesh D:\poisson\point_cloud_160_mesh.obj: Surface Area = 510584.13470942824
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_161_mesh.obj
# Mesh D:\poisson\point_cloud_161_mesh.obj: Surface Area = 518686.1928726301
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_162_mesh.obj
# Mesh D:\poisson\point_cloud_162_mesh.obj: Surface Area = 584028.6281109849
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_163_mesh.obj
# Mesh D:\poisson\point_cloud_163_mesh.obj: Surface Area = 569638.6545012355
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_164_mesh.obj
# Mesh D:\poisson\point_cloud_164_mesh.obj: Surface Area = 804730.0315888734
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_165_mesh.obj
# Mesh D:\poisson\point_cloud_165_mesh.obj: Surface Area = 538496.0803443269
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_166_mesh.obj
# Mesh D:\poisson\point_cloud_166_mesh.obj: Surface Area = 542525.7919156498
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_167_mesh.obj
# Mesh D:\poisson\point_cloud_167_mesh.obj: Surface Area = 513696.82486316934
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_168_mesh.obj
# Mesh D:\poisson\point_cloud_168_mesh.obj: Surface Area = 508621.18948423053
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_169_mesh.obj
# Mesh D:\poisson\point_cloud_169_mesh.obj: Surface Area = 528162.137991312
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_17_mesh.obj
# Mesh D:\poisson\point_cloud_17_mesh.obj: Surface Area = 544690.9674094006
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_170_mesh.obj
# Mesh D:\poisson\point_cloud_170_mesh.obj: Surface Area = 525291.255278057
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_171_mesh.obj
# Mesh D:\poisson\point_cloud_171_mesh.obj: Surface Area = 534630.8252071477
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_172_mesh.obj
# Mesh D:\poisson\point_cloud_172_mesh.obj: Surface Area = 538000.1003922486
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_173_mesh.obj
# Mesh D:\poisson\point_cloud_173_mesh.obj: Surface Area = 526196.3212084816
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_174_mesh.obj
# Mesh D:\poisson\point_cloud_174_mesh.obj: Surface Area = 517942.00219237554
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_175_mesh.obj
# Mesh D:\poisson\point_cloud_175_mesh.obj: Surface Area = 521615.44049626734
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_176_mesh.obj
# Mesh D:\poisson\point_cloud_176_mesh.obj: Surface Area = 604773.1649969461
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_177_mesh.obj
# Mesh D:\poisson\point_cloud_177_mesh.obj: Surface Area = 540499.9904134487
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_178_mesh.obj
# Mesh D:\poisson\point_cloud_178_mesh.obj: Surface Area = 509100.79796704033
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_179_mesh.obj
# Mesh D:\poisson\point_cloud_179_mesh.obj: Surface Area = 550045.0298468074
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_18_mesh.obj
# Mesh D:\poisson\point_cloud_18_mesh.obj: Surface Area = 539548.9487198611
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_180_mesh.obj
# Mesh D:\poisson\point_cloud_180_mesh.obj: Surface Area = 515643.1144526407
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_181_mesh.obj
# Mesh D:\poisson\point_cloud_181_mesh.obj: Surface Area = 521003.4833718575
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_182_mesh.obj
# Mesh D:\poisson\point_cloud_182_mesh.obj: Surface Area = 521582.8712877791
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_183_mesh.obj
# Mesh D:\poisson\point_cloud_183_mesh.obj: Surface Area = 511577.2900399392
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_184_mesh.obj
# Mesh D:\poisson\point_cloud_184_mesh.obj: Surface Area = 660018.1883162598
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_185_mesh.obj
# Mesh D:\poisson\point_cloud_185_mesh.obj: Surface Area = 556803.311060451
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_186_mesh.obj
# Mesh D:\poisson\point_cloud_186_mesh.obj: Surface Area = 601691.8285935866
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_187_mesh.obj
# Mesh D:\poisson\point_cloud_187_mesh.obj: Surface Area = 516100.08045633615
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_188_mesh.obj
# Mesh D:\poisson\point_cloud_188_mesh.obj: Surface Area = 522209.2915380252
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_189_mesh.obj
# Mesh D:\poisson\point_cloud_189_mesh.obj: Surface Area = 534320.787509822
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_19_mesh.obj
# Mesh D:\poisson\point_cloud_19_mesh.obj: Surface Area = 506653.5085008428
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_190_mesh.obj
# Mesh D:\poisson\point_cloud_190_mesh.obj: Surface Area = 520121.29802343633
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_191_mesh.obj
# Mesh D:\poisson\point_cloud_191_mesh.obj: Surface Area = 509638.82069167745
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_192_mesh.obj
# Mesh D:\poisson\point_cloud_192_mesh.obj: Surface Area = 519880.4200034915
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_193_mesh.obj
# Mesh D:\poisson\point_cloud_193_mesh.obj: Surface Area = 572856.0920542188
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_194_mesh.obj
# Mesh D:\poisson\point_cloud_194_mesh.obj: Surface Area = 533687.6213856832
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_195_mesh.obj
# Mesh D:\poisson\point_cloud_195_mesh.obj: Surface Area = 776514.0300090748
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_196_mesh.obj
# Mesh D:\poisson\point_cloud_196_mesh.obj: Surface Area = 542400.178647793
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_197_mesh.obj
# Mesh D:\poisson\point_cloud_197_mesh.obj: Surface Area = 497602.0461701913
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_198_mesh.obj
# Mesh D:\poisson\point_cloud_198_mesh.obj: Surface Area = 518042.70312124677
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_199_mesh.obj
# Mesh D:\poisson\point_cloud_199_mesh.obj: Surface Area = 565303.413290515
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_2_mesh.obj
# Mesh D:\poisson\point_cloud_2_mesh.obj: Surface Area = 512943.20186583436
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_20_mesh.obj
# Mesh D:\poisson\point_cloud_20_mesh.obj: Surface Area = 508789.19078542327
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_200_mesh.obj
# Mesh D:\poisson\point_cloud_200_mesh.obj: Surface Area = 554929.2292217474
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_201_mesh.obj
# Mesh D:\poisson\point_cloud_201_mesh.obj: Surface Area = 536755.7181069562
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_202_mesh.obj
# Mesh D:\poisson\point_cloud_202_mesh.obj: Surface Area = 559057.0034617577
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_203_mesh.obj
# Mesh D:\poisson\point_cloud_203_mesh.obj: Surface Area = 514925.08812792454
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_204_mesh.obj
# Mesh D:\poisson\point_cloud_204_mesh.obj: Surface Area = 516511.07409715303
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_205_mesh.obj
# Mesh D:\poisson\point_cloud_205_mesh.obj: Surface Area = 518571.87626731134
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_206_mesh.obj
# Mesh D:\poisson\point_cloud_206_mesh.obj: Surface Area = 632872.8341510219
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_207_mesh.obj
# Mesh D:\poisson\point_cloud_207_mesh.obj: Surface Area = 522713.87262561993
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_208_mesh.obj
# Mesh D:\poisson\point_cloud_208_mesh.obj: Surface Area = 548880.7616050228
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_209_mesh.obj
# Mesh D:\poisson\point_cloud_209_mesh.obj: Surface Area = 516668.5656089997
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_21_mesh.obj
# Mesh D:\poisson\point_cloud_21_mesh.obj: Surface Area = 581307.5365573738
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_210_mesh.obj
# Mesh D:\poisson\point_cloud_210_mesh.obj: Surface Area = 561691.3718985617
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_211_mesh.obj
# Mesh D:\poisson\point_cloud_211_mesh.obj: Surface Area = 515154.4215950983
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_212_mesh.obj
# Mesh D:\poisson\point_cloud_212_mesh.obj: Surface Area = 541973.9833919591
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_213_mesh.obj
# Mesh D:\poisson\point_cloud_213_mesh.obj: Surface Area = 515782.2200003887
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_214_mesh.obj
# Mesh D:\poisson\point_cloud_214_mesh.obj: Surface Area = 521394.279366401
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_215_mesh.obj
# Mesh D:\poisson\point_cloud_215_mesh.obj: Surface Area = 529929.4718932338
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_216_mesh.obj
# Mesh D:\poisson\point_cloud_216_mesh.obj: Surface Area = 564261.0102971554
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_217_mesh.obj
# Mesh D:\poisson\point_cloud_217_mesh.obj: Surface Area = 514356.1473548478
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_218_mesh.obj
# Mesh D:\poisson\point_cloud_218_mesh.obj: Surface Area = 527098.5595507155
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_219_mesh.obj
# Mesh D:\poisson\point_cloud_219_mesh.obj: Surface Area = 540219.8750973449
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_22_mesh.obj
# Mesh D:\poisson\point_cloud_22_mesh.obj: Surface Area = 565185.9888836016
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_220_mesh.obj
# Mesh D:\poisson\point_cloud_220_mesh.obj: Surface Area = 505214.06033475936
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_221_mesh.obj
# Mesh D:\poisson\point_cloud_221_mesh.obj: Surface Area = 529430.1073126795
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_222_mesh.obj
# Mesh D:\poisson\point_cloud_222_mesh.obj: Surface Area = 511013.34138118365
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_223_mesh.obj
# Mesh D:\poisson\point_cloud_223_mesh.obj: Surface Area = 538382.4100404994
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_224_mesh.obj
# Mesh D:\poisson\point_cloud_224_mesh.obj: Surface Area = 537120.2302187731
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_225_mesh.obj
# Mesh D:\poisson\point_cloud_225_mesh.obj: Surface Area = 550867.8454419513
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_226_mesh.obj
# Mesh D:\poisson\point_cloud_226_mesh.obj: Surface Area = 561123.1521087514
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_227_mesh.obj
# Mesh D:\poisson\point_cloud_227_mesh.obj: Surface Area = 566836.0349727606
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_228_mesh.obj
# Mesh D:\poisson\point_cloud_228_mesh.obj: Surface Area = 582559.9249451612
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_229_mesh.obj
# Mesh D:\poisson\point_cloud_229_mesh.obj: Surface Area = 536696.3962714967
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_23_mesh.obj
# Mesh D:\poisson\point_cloud_23_mesh.obj: Surface Area = 550315.2921619051
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_230_mesh.obj
# Mesh D:\poisson\point_cloud_230_mesh.obj: Surface Area = 540692.9964418889
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_231_mesh.obj
# Mesh D:\poisson\point_cloud_231_mesh.obj: Surface Area = 544644.5434123069
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_232_mesh.obj
# Mesh D:\poisson\point_cloud_232_mesh.obj: Surface Area = 555950.6731255115
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_233_mesh.obj
# Mesh D:\poisson\point_cloud_233_mesh.obj: Surface Area = 567348.2673832483
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_234_mesh.obj
# Mesh D:\poisson\point_cloud_234_mesh.obj: Surface Area = 542626.8019407335
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_235_mesh.obj
# Mesh D:\poisson\point_cloud_235_mesh.obj: Surface Area = 568392.3677493305
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_236_mesh.obj
# Mesh D:\poisson\point_cloud_236_mesh.obj: Surface Area = 515823.78950910806
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_237_mesh.obj
# Mesh D:\poisson\point_cloud_237_mesh.obj: Surface Area = 552605.1789832755
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_238_mesh.obj
# Mesh D:\poisson\point_cloud_238_mesh.obj: Surface Area = 559997.4155700405
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_239_mesh.obj
# Mesh D:\poisson\point_cloud_239_mesh.obj: Surface Area = 535314.5378849041
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_24_mesh.obj
# Mesh D:\poisson\point_cloud_24_mesh.obj: Surface Area = 503799.01561239985
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_240_mesh.obj
# Mesh D:\poisson\point_cloud_240_mesh.obj: Surface Area = 528317.8720532907
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_241_mesh.obj
# Mesh D:\poisson\point_cloud_241_mesh.obj: Surface Area = 520536.9808914256
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_242_mesh.obj
# Mesh D:\poisson\point_cloud_242_mesh.obj: Surface Area = 508929.6817388569
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_243_mesh.obj
# Mesh D:\poisson\point_cloud_243_mesh.obj: Surface Area = 513697.63797643525
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_244_mesh.obj
# Mesh D:\poisson\point_cloud_244_mesh.obj: Surface Area = 524698.7130715668
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_245_mesh.obj
# Mesh D:\poisson\point_cloud_245_mesh.obj: Surface Area = 539695.0050305577
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_246_mesh.obj
# Mesh D:\poisson\point_cloud_246_mesh.obj: Surface Area = 552516.6790485911
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_247_mesh.obj
# Mesh D:\poisson\point_cloud_247_mesh.obj: Surface Area = 523183.6034269385
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_248_mesh.obj
# Mesh D:\poisson\point_cloud_248_mesh.obj: Surface Area = 547432.6530485989
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_249_mesh.obj
# Mesh D:\poisson\point_cloud_249_mesh.obj: Surface Area = 544983.4692117408
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_25_mesh.obj
# Mesh D:\poisson\point_cloud_25_mesh.obj: Surface Area = 515295.42828068393
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_250_mesh.obj
# Mesh D:\poisson\point_cloud_250_mesh.obj: Surface Area = 519793.2097049246
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_251_mesh.obj
# Mesh D:\poisson\point_cloud_251_mesh.obj: Surface Area = 546124.5377917816
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_252_mesh.obj
# Mesh D:\poisson\point_cloud_252_mesh.obj: Surface Area = 529414.2495818058
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_253_mesh.obj
# Mesh D:\poisson\point_cloud_253_mesh.obj: Surface Area = 609248.9489908321
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_254_mesh.obj
# Mesh D:\poisson\point_cloud_254_mesh.obj: Surface Area = 530033.413193797
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_255_mesh.obj
# Mesh D:\poisson\point_cloud_255_mesh.obj: Surface Area = 559763.0003913583
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_256_mesh.obj
# Mesh D:\poisson\point_cloud_256_mesh.obj: Surface Area = 525718.4403936961
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_257_mesh.obj
# Mesh D:\poisson\point_cloud_257_mesh.obj: Surface Area = 518122.19852133194
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_258_mesh.obj
# Mesh D:\poisson\point_cloud_258_mesh.obj: Surface Area = 537823.4254868544
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_259_mesh.obj
# Mesh D:\poisson\point_cloud_259_mesh.obj: Surface Area = 527522.7798373956
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_26_mesh.obj
# Mesh D:\poisson\point_cloud_26_mesh.obj: Surface Area = 575998.2791420892
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_260_mesh.obj
# Mesh D:\poisson\point_cloud_260_mesh.obj: Surface Area = 545714.4188243216
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_261_mesh.obj
# Mesh D:\poisson\point_cloud_261_mesh.obj: Surface Area = 516569.81863187964
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_262_mesh.obj
# Mesh D:\poisson\point_cloud_262_mesh.obj: Surface Area = 520129.85603752703
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_263_mesh.obj
# Mesh D:\poisson\point_cloud_263_mesh.obj: Surface Area = 515252.5327471301
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_264_mesh.obj
# Mesh D:\poisson\point_cloud_264_mesh.obj: Surface Area = 533743.8831342079
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_265_mesh.obj
# Mesh D:\poisson\point_cloud_265_mesh.obj: Surface Area = 538905.4761549693
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_266_mesh.obj
# Mesh D:\poisson\point_cloud_266_mesh.obj: Surface Area = 567271.3137247936
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_267_mesh.obj
# Mesh D:\poisson\point_cloud_267_mesh.obj: Surface Area = 548676.3375800687
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_268_mesh.obj
# Mesh D:\poisson\point_cloud_268_mesh.obj: Surface Area = 532301.516095107
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_269_mesh.obj
# Mesh D:\poisson\point_cloud_269_mesh.obj: Surface Area = 517328.3136112207
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_27_mesh.obj
# Mesh D:\poisson\point_cloud_27_mesh.obj: Surface Area = 594852.1686269698
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_270_mesh.obj
# Mesh D:\poisson\point_cloud_270_mesh.obj: Surface Area = 532047.7386350612
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_271_mesh.obj
# Mesh D:\poisson\point_cloud_271_mesh.obj: Surface Area = 537022.776171214
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_272_mesh.obj
# Mesh D:\poisson\point_cloud_272_mesh.obj: Surface Area = 552449.3075489261
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_273_mesh.obj
# Mesh D:\poisson\point_cloud_273_mesh.obj: Surface Area = 548335.7221046175
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_274_mesh.obj
# Mesh D:\poisson\point_cloud_274_mesh.obj: Surface Area = 569876.4584133798
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_275_mesh.obj
# Mesh D:\poisson\point_cloud_275_mesh.obj: Surface Area = 544475.598347398
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_276_mesh.obj
# Mesh D:\poisson\point_cloud_276_mesh.obj: Surface Area = 557038.3527949919
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_277_mesh.obj
# Mesh D:\poisson\point_cloud_277_mesh.obj: Surface Area = 556625.5436920866
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_278_mesh.obj
# Mesh D:\poisson\point_cloud_278_mesh.obj: Surface Area = 558813.2013229929
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_279_mesh.obj
# Mesh D:\poisson\point_cloud_279_mesh.obj: Surface Area = 570504.6288731216
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_28_mesh.obj
# Mesh D:\poisson\point_cloud_28_mesh.obj: Surface Area = 550224.9853701328
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_280_mesh.obj
# Mesh D:\poisson\point_cloud_280_mesh.obj: Surface Area = 511893.4319699841
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_281_mesh.obj
# Mesh D:\poisson\point_cloud_281_mesh.obj: Surface Area = 515545.9086961602
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_282_mesh.obj
# Mesh D:\poisson\point_cloud_282_mesh.obj: Surface Area = 520207.5664034055
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_283_mesh.obj
# Mesh D:\poisson\point_cloud_283_mesh.obj: Surface Area = 519663.91509399697
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_284_mesh.obj
# Mesh D:\poisson\point_cloud_284_mesh.obj: Surface Area = 522009.4917482422
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_285_mesh.obj
# Mesh D:\poisson\point_cloud_285_mesh.obj: Surface Area = 506288.0961319286
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_286_mesh.obj
# Mesh D:\poisson\point_cloud_286_mesh.obj: Surface Area = 516084.0896314109
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_287_mesh.obj
# Mesh D:\poisson\point_cloud_287_mesh.obj: Surface Area = 523082.2496919001
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_288_mesh.obj
# Mesh D:\poisson\point_cloud_288_mesh.obj: Surface Area = 521294.4670434224
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_289_mesh.obj
# Mesh D:\poisson\point_cloud_289_mesh.obj: Surface Area = 535291.6726493936
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_29_mesh.obj
# Mesh D:\poisson\point_cloud_29_mesh.obj: Surface Area = 575006.7978255325
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_290_mesh.obj
# Mesh D:\poisson\point_cloud_290_mesh.obj: Surface Area = 541102.3752004735
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_291_mesh.obj
# Mesh D:\poisson\point_cloud_291_mesh.obj: Surface Area = 525455.4146710606
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_292_mesh.obj
# Mesh D:\poisson\point_cloud_292_mesh.obj: Surface Area = 520852.4031725586
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_293_mesh.obj
# Mesh D:\poisson\point_cloud_293_mesh.obj: Surface Area = 526534.1048189675
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_294_mesh.obj
# Mesh D:\poisson\point_cloud_294_mesh.obj: Surface Area = 523365.8761648204
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_295_mesh.obj
# Mesh D:\poisson\point_cloud_295_mesh.obj: Surface Area = 575652.2322933213
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_296_mesh.obj
# Mesh D:\poisson\point_cloud_296_mesh.obj: Surface Area = 531905.807387157
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_297_mesh.obj
# Mesh D:\poisson\point_cloud_297_mesh.obj: Surface Area = 513836.0658544518
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_298_mesh.obj
# Mesh D:\poisson\point_cloud_298_mesh.obj: Surface Area = 530953.3502976291
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_299_mesh.obj
# Mesh D:\poisson\point_cloud_299_mesh.obj: Surface Area = 524455.3734149699
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_3_mesh.obj
# Mesh D:\poisson\point_cloud_3_mesh.obj: Surface Area = 599414.7280279023
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_30_mesh.obj
# Mesh D:\poisson\point_cloud_30_mesh.obj: Surface Area = 584432.5250769842
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_300_mesh.obj
# Mesh D:\poisson\point_cloud_300_mesh.obj: Surface Area = 548649.9292162127
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_301_mesh.obj
# Mesh D:\poisson\point_cloud_301_mesh.obj: Surface Area = 538586.1161445199
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_302_mesh.obj
# Mesh D:\poisson\point_cloud_302_mesh.obj: Surface Area = 536681.1849973804
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_303_mesh.obj
# Mesh D:\poisson\point_cloud_303_mesh.obj: Surface Area = 540612.290306914
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_304_mesh.obj
# Mesh D:\poisson\point_cloud_304_mesh.obj: Surface Area = 547917.7163257238
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_305_mesh.obj
# Mesh D:\poisson\point_cloud_305_mesh.obj: Surface Area = 522013.3958090069
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_306_mesh.obj
# Mesh D:\poisson\point_cloud_306_mesh.obj: Surface Area = 523152.41269453487
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_307_mesh.obj
# Mesh D:\poisson\point_cloud_307_mesh.obj: Surface Area = 548999.8920527713
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_308_mesh.obj
# Mesh D:\poisson\point_cloud_308_mesh.obj: Surface Area = 532186.8967153408
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_309_mesh.obj
# Mesh D:\poisson\point_cloud_309_mesh.obj: Surface Area = 518998.88548658404
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_31_mesh.obj
# Mesh D:\poisson\point_cloud_31_mesh.obj: Surface Area = 559178.1352738739
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_310_mesh.obj
# Mesh D:\poisson\point_cloud_310_mesh.obj: Surface Area = 537825.0385242495
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_311_mesh.obj
# Mesh D:\poisson\point_cloud_311_mesh.obj: Surface Area = 532593.5941712359
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_312_mesh.obj
# Mesh D:\poisson\point_cloud_312_mesh.obj: Surface Area = 515445.414709698
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_313_mesh.obj
# Mesh D:\poisson\point_cloud_313_mesh.obj: Surface Area = 515601.6166818394
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_314_mesh.obj
# Mesh D:\poisson\point_cloud_314_mesh.obj: Surface Area = 522162.0284960532
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_315_mesh.obj
# Mesh D:\poisson\point_cloud_315_mesh.obj: Surface Area = 517415.59390826133
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_316_mesh.obj
# Mesh D:\poisson\point_cloud_316_mesh.obj: Surface Area = 525512.9527945882
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_317_mesh.obj
# Mesh D:\poisson\point_cloud_317_mesh.obj: Surface Area = 530603.861908276
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_318_mesh.obj
# Mesh D:\poisson\point_cloud_318_mesh.obj: Surface Area = 534490.651563485
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_319_mesh.obj
# Mesh D:\poisson\point_cloud_319_mesh.obj: Surface Area = 536862.940971498
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_32_mesh.obj
# Mesh D:\poisson\point_cloud_32_mesh.obj: Surface Area = 587742.3337694589
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_320_mesh.obj
# Mesh D:\poisson\point_cloud_320_mesh.obj: Surface Area = 522028.4152520283
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_321_mesh.obj
# Mesh D:\poisson\point_cloud_321_mesh.obj: Surface Area = 515970.4005420412
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_322_mesh.obj
# ...
# Mesh D:\poisson\point_cloud_474_mesh.obj: Surface Area = 533834.895162679
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_475_mesh.obj
# Mesh D:\poisson\point_cloud_475_mesh.obj: Surface Area = 529317.5785364809
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_476_mesh.obj
# Mesh D:\poisson\point_cloud_476_mesh.obj: Surface Area = 521427.81516491884
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_477_mesh.obj
# Mesh D:\poisson\point_cloud_477_mesh.obj: Surface Area = 565923.638587775
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_478_mesh.obj
# Mesh D:\poisson\point_cloud_478_mesh.obj: Surface Area = 520196.4809242621
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_479_mesh.obj
# Mesh D:\poisson\point_cloud_479_mesh.obj: Surface Area = 519758.3055705978
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_48_mesh.obj
# Mesh D:\poisson\point_cloud_48_mesh.obj: Surface Area = 572879.5599348283
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_480_mesh.obj
# Mesh D:\poisson\point_cloud_480_mesh.obj: Surface Area = 500133.5541992155
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_481_mesh.obj
# Mesh D:\poisson\point_cloud_481_mesh.obj: Surface Area = 518588.3857429168
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_482_mesh.obj
# Mesh D:\poisson\point_cloud_482_mesh.obj: Surface Area = 536225.8755212701
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_483_mesh.obj
# Mesh D:\poisson\point_cloud_483_mesh.obj: Surface Area = 526387.0032873172
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_484_mesh.obj
# Mesh D:\poisson\point_cloud_484_mesh.obj: Surface Area = 591543.1937348879
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_485_mesh.obj
# Mesh D:\poisson\point_cloud_485_mesh.obj: Surface Area = 556022.1197488697
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_486_mesh.obj
# Mesh D:\poisson\point_cloud_486_mesh.obj: Surface Area = 509441.2714240373
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_487_mesh.obj
# Mesh D:\poisson\point_cloud_487_mesh.obj: Surface Area = 508897.14373273175
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_488_mesh.obj
# Mesh D:\poisson\point_cloud_488_mesh.obj: Surface Area = 524529.9120266578
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_489_mesh.obj
# Mesh D:\poisson\point_cloud_489_mesh.obj: Surface Area = 516905.52545233374
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_49_mesh.obj
# Mesh D:\poisson\point_cloud_49_mesh.obj: Surface Area = 512251.58999369555
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_490_mesh.obj
# Mesh D:\poisson\point_cloud_490_mesh.obj: Surface Area = 548444.2709812097
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_491_mesh.obj
# Mesh D:\poisson\point_cloud_491_mesh.obj: Surface Area = 544285.4015307253
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_492_mesh.obj
# Mesh D:\poisson\point_cloud_492_mesh.obj: Surface Area = 523081.57020111044
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_493_mesh.obj
# Mesh D:\poisson\point_cloud_493_mesh.obj: Surface Area = 518213.60307621
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_494_mesh.obj
# Mesh D:\poisson\point_cloud_494_mesh.obj: Surface Area = 529211.4316346715
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_495_mesh.obj
# Mesh D:\poisson\point_cloud_495_mesh.obj: Surface Area = 559120.2766719871
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_496_mesh.obj
# Mesh D:\poisson\point_cloud_496_mesh.obj: Surface Area = 526264.386339241
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_497_mesh.obj
# Mesh D:\poisson\point_cloud_497_mesh.obj: Surface Area = 509604.6620885629
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_498_mesh.obj
# Mesh D:\poisson\point_cloud_498_mesh.obj: Surface Area = 500916.43965723884
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_499_mesh.obj
# Mesh D:\poisson\point_cloud_499_mesh.obj: Surface Area = 513008.1129173344
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_5_mesh.obj
# Mesh D:\poisson\point_cloud_5_mesh.obj: Surface Area = 518569.1492495691
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_50_mesh.obj
# Mesh D:\poisson\point_cloud_50_mesh.obj: Surface Area = 540404.8445843197
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_500_mesh.obj
# Mesh D:\poisson\point_cloud_500_mesh.obj: Surface Area = 556607.4433378355
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_51_mesh.obj
# Mesh D:\poisson\point_cloud_51_mesh.obj: Surface Area = 515819.5848737282
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_52_mesh.obj
# Mesh D:\poisson\point_cloud_52_mesh.obj: Surface Area = 528653.4322378723
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_53_mesh.obj
# Mesh D:\poisson\point_cloud_53_mesh.obj: Surface Area = 533162.6877224948
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_54_mesh.obj
# Mesh D:\poisson\point_cloud_54_mesh.obj: Surface Area = 566121.1994614117
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_55_mesh.obj
# Mesh D:\poisson\point_cloud_55_mesh.obj: Surface Area = 515704.18583147135
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_56_mesh.obj
# Mesh D:\poisson\point_cloud_56_mesh.obj: Surface Area = 518203.5615685768
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_57_mesh.obj
# Mesh D:\poisson\point_cloud_57_mesh.obj: Surface Area = 526302.8216206792
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_58_mesh.obj
# Mesh D:\poisson\point_cloud_58_mesh.obj: Surface Area = 537828.9050397183
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_59_mesh.obj
# Mesh D:\poisson\point_cloud_59_mesh.obj: Surface Area = 516789.6451773353
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_6_mesh.obj
# Mesh D:\poisson\point_cloud_6_mesh.obj: Surface Area = 577068.2353420064
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_60_mesh.obj
# Mesh D:\poisson\point_cloud_60_mesh.obj: Surface Area = 527408.8570626617
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_61_mesh.obj
# Mesh D:\poisson\point_cloud_61_mesh.obj: Surface Area = 512179.6098717175
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_62_mesh.obj
# Mesh D:\poisson\point_cloud_62_mesh.obj: Surface Area = 520061.00078475673
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_63_mesh.obj
# Mesh D:\poisson\point_cloud_63_mesh.obj: Surface Area = 586741.2205868106
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_64_mesh.obj
# Mesh D:\poisson\point_cloud_64_mesh.obj: Surface Area = 536292.0916081985
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_65_mesh.obj
# Mesh D:\poisson\point_cloud_65_mesh.obj: Surface Area = 520243.4741783079
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_66_mesh.obj
# Mesh D:\poisson\point_cloud_66_mesh.obj: Surface Area = 510506.6522417328
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_67_mesh.obj
# Mesh D:\poisson\point_cloud_67_mesh.obj: Surface Area = 544107.6505325972
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_68_mesh.obj
# Mesh D:\poisson\point_cloud_68_mesh.obj: Surface Area = 518224.9314813238
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_69_mesh.obj
# Mesh D:\poisson\point_cloud_69_mesh.obj: Surface Area = 505601.26100224577
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_7_mesh.obj
# Mesh D:\poisson\point_cloud_7_mesh.obj: Surface Area = 522780.3693353349
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_70_mesh.obj
# Mesh D:\poisson\point_cloud_70_mesh.obj: Surface Area = 530634.4993501258
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_71_mesh.obj
# Mesh D:\poisson\point_cloud_71_mesh.obj: Surface Area = 547533.2986849056
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_72_mesh.obj
# Mesh D:\poisson\point_cloud_72_mesh.obj: Surface Area = 520102.35448100907
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_73_mesh.obj
# Mesh D:\poisson\point_cloud_73_mesh.obj: Surface Area = 517611.1003741172
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_74_mesh.obj
# Mesh D:\poisson\point_cloud_74_mesh.obj: Surface Area = 522243.9458821949
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_75_mesh.obj
# Mesh D:\poisson\point_cloud_75_mesh.obj: Surface Area = 542588.6328227506
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_76_mesh.obj
# Mesh D:\poisson\point_cloud_76_mesh.obj: Surface Area = 515223.0983195695
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_77_mesh.obj
# Mesh D:\poisson\point_cloud_77_mesh.obj: Surface Area = 534050.0306751423
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_78_mesh.obj
# Mesh D:\poisson\point_cloud_78_mesh.obj: Surface Area = 525433.5484673862
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_79_mesh.obj
# Mesh D:\poisson\point_cloud_79_mesh.obj: Surface Area = 534502.0763203205
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_8_mesh.obj
# Mesh D:\poisson\point_cloud_8_mesh.obj: Surface Area = 519224.0939474076
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_80_mesh.obj
# Mesh D:\poisson\point_cloud_80_mesh.obj: Surface Area = 523232.70237485843
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_81_mesh.obj
# Mesh D:\poisson\point_cloud_81_mesh.obj: Surface Area = 518819.3411117426
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_82_mesh.obj
# Mesh D:\poisson\point_cloud_82_mesh.obj: Surface Area = 517216.3559795572
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_83_mesh.obj
# Mesh D:\poisson\point_cloud_83_mesh.obj: Surface Area = 515958.7063549589
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_84_mesh.obj
# Mesh D:\poisson\point_cloud_84_mesh.obj: Surface Area = 546411.542379645
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_85_mesh.obj
# Mesh D:\poisson\point_cloud_85_mesh.obj: Surface Area = 556722.4352487013
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_86_mesh.obj
# Mesh D:\poisson\point_cloud_86_mesh.obj: Surface Area = 539212.0139098306
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_87_mesh.obj
# Mesh D:\poisson\point_cloud_87_mesh.obj: Surface Area = 551018.7527935443
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_88_mesh.obj
# Mesh D:\poisson\point_cloud_88_mesh.obj: Surface Area = 557949.0280432844
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_89_mesh.obj
# Mesh D:\poisson\point_cloud_89_mesh.obj: Surface Area = 569895.3772684897
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_9_mesh.obj
# Mesh D:\poisson\point_cloud_9_mesh.obj: Surface Area = 525035.5222213712
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_90_mesh.obj
# Mesh D:\poisson\point_cloud_90_mesh.obj: Surface Area = 562049.2678604799
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_91_mesh.obj
# Mesh D:\poisson\point_cloud_91_mesh.obj: Surface Area = 572087.6693098365
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_92_mesh.obj
# Mesh D:\poisson\point_cloud_92_mesh.obj: Surface Area = 555754.9139185442
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_93_mesh.obj
# Mesh D:\poisson\point_cloud_93_mesh.obj: Surface Area = 543166.2695708501
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_94_mesh.obj
# Mesh D:\poisson\point_cloud_94_mesh.obj: Surface Area = 573570.3401150523
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_95_mesh.obj
# Mesh D:\poisson\point_cloud_95_mesh.obj: Surface Area = 556619.9302871416
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_96_mesh.obj
# Mesh D:\poisson\point_cloud_96_mesh.obj: Surface Area = 549495.6787027299
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_97_mesh.obj
# Mesh D:\poisson\point_cloud_97_mesh.obj: Surface Area = 545503.3515826359
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_98_mesh.obj
# Mesh D:\poisson\point_cloud_98_mesh.obj: Surface Area = 553774.7124634465
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\poisson\point_cloud_99_mesh.obj
# Mesh D:\poisson\point_cloud_99_mesh.obj: Surface Area = 533513.1689505616

# %% [markdown]
# ## Heatmap with Poisson Surface Reconstruction

# %%
import os
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt

def set_mesh_color(mesh, depths):
    # Normalize depths between 0 and 1
    min_depth = np.min(depths)
    max_depth = np.max(depths)
    #print(f"Min depth: {min_depth}, Max depth: {max_depth}")
    normalized_depths = (depths - min_depth) / (max_depth - min_depth)
    
    # Use Matplotlib colormap
    colormap = plt.get_cmap('jet')
    colors = colormap(normalized_depths)[:, :3]  # Get RGB values (discard alpha channel)
    
    #print(f"Sample normalized depth: {normalized_depths[:10]}")
    #print(f"Sample colors: {colors[:10]}")
    
    # Ensure the colors are correctly assigned
    mesh.vertex_colors = o3d.utility.Vector3dVector(colors)
    #print(f"Assigned vertex colors (sample): {np.asarray(mesh.vertex_colors)[:10]}")

def process_point_cloud(ply_file, output_mesh_file):
    # Load point cloud
    pcd = o3d.io.read_point_cloud(ply_file)
    
    # Downsample
    pcd = pcd.voxel_down_sample(voxel_size=0.02)
    
    # Noise removal
    pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
    
    # Estimate normals
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Surface reconstruction using Poisson method
    mesh, densities = o3d.geometry.TriangleMesh.create_from_point_cloud_poisson(pcd, depth=9)
    
    # Check if the mesh has vertices
    if not mesh.has_vertices():
        print(f"No vertices found in the generated mesh for {ply_file}. Skipping.")
        return
    
    mesh.compute_vertex_normals()
    
    # Get depth values (distance from the camera)
    depths = np.asarray(pcd.points)[:, 2]  # Assuming z-coordinate is depth
    
    # Set the mesh color based on depth
    set_mesh_color(mesh, depths)
    
    # Save the mesh
    o3d.io.write_triangle_mesh(output_mesh_file, mesh, write_vertex_normals=True, write_vertex_colors=True)
    
    print(f"Processed and saved: {output_mesh_file}")

    # Visualize the mesh directly
    o3d.visualization.draw_geometries([mesh], mesh_show_back_face=True)

def visualize_point_cloud(pcd):
    o3d.visualization.draw_geometries([pcd], point_show_normal=True)

# Directory paths
input_ply_dir = r"D:\ply3"
output_mesh_dir = r"D:\depth"

# Ensure output directory exists
os.makedirs(output_mesh_dir, exist_ok=True)

# Process each point cloud
for ply_file in os.listdir(input_ply_dir):
    if ply_file.endswith(".ply"):
        ply_file_path = os.path.join(input_ply_dir, ply_file)
        output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_mesh.obj"))
        
        # Load point cloud for color visualization
        pcd = o3d.io.read_point_cloud(ply_file_path)
        depths = np.asarray(pcd.points)[:, 2]
        colormap = plt.get_cmap('jet')
        normalized_depths = (depths - np.min(depths)) / (np.max(depths) - np.min(depths))
        colors = colormap(normalized_depths)[:, :3]
        pcd.colors = o3d.utility.Vector3dVector(colors)
        
        # Visualize point cloud colors
        visualize_point_cloud(pcd)
        
        process_point_cloud(ply_file_path, output_mesh_file)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D WARNING] Write OBJ can not include triangle normals.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 88
#      85 # Visualize point cloud colors
#      86 visualize_point_cloud(pcd)
# ---> 88 process_point_cloud(ply_file_path, output_mesh_file)
#
# Cell In[1], line 54, in process_point_cloud(ply_file, output_mesh_file)
#      51 set_mesh_color(mesh, depths)
#      53 # Save the mesh
# ---> 54 o3d.io.write_triangle_mesh(output_mesh_file, mesh, write_vertex_normals=True, write_vertex_colors=True)
#      56 print(f"Processed and saved: {output_mesh_file}")
#      58 # Visualize the mesh directly
#
# KeyboardInterrupt:

# %% [markdown]
# ## Ball Pivot Algorithm Result

# %%
import os
import open3d as o3d
import numpy as np
import pymeshlab

def process_point_cloud(ply_file, output_mesh_file):
    # Load point cloud from PLY file
    pcd = o3d.io.read_point_cloud(ply_file)
    
    # Downsample the point cloud to reduce the number of points
    pcd = pcd.voxel_down_sample(voxel_size=0.02)
    
    # Remove noise from the point cloud using statistical outlier removal
    pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
    
    # Estimate normals for the downsampled and denoised point cloud
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Surface reconstruction using the Ball-Pivoting Algorithm (BPA)
    distances = pcd.compute_nearest_neighbor_distance()
    avg_dist = np.mean(distances)
    radius = 3 * avg_dist
    bpa_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
        pcd, o3d.utility.DoubleVector([radius, radius * 2, radius * 3]))
    bpa_mesh.compute_vertex_normals()
    
    # Save the BPA mesh to an OBJ file
    o3d.io.write_triangle_mesh(output_mesh_file, bpa_mesh)
    
    print(f"Processed and saved: {output_mesh_file}")

# Function to visualize a mesh
def visualize_mesh(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()
    o3d.visualization.draw_geometries([mesh])

# Function to compute properties of the mesh
def compute_properties(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()

    # Surface area
    surface_area = mesh.get_surface_area()
    
    return surface_area

# Directory paths
input_ply_dir = r"D:\ply3"
output_mesh_dir = r"D:\mamaji"

# Ensure the output directory exists
os.makedirs(output_mesh_dir, exist_ok=True)

# Process each point cloud file in the input directory
for ply_file in os.listdir(input_ply_dir):
    if ply_file.endswith(".ply"):
        ply_file_path = os.path.join(input_ply_dir, ply_file)
        output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_mesh.obj"))
        
        process_point_cloud(ply_file_path, output_mesh_file)
        
        # Visualize the mesh
        visualize_mesh(output_mesh_file)
        
        # Compute properties and handle non-watertight meshes
        surface_area = compute_properties(output_mesh_file)
        print(f"Mesh {output_mesh_file}: Surface Area = {surface_area}")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\mamaji\point_cloud_1_mesh.obj
# Mesh D:\mamaji\point_cloud_1_mesh.obj: Surface Area = 305370.4631916391
# [Open3D WARNING] Write OBJ can not include triangle normals.
# Processed and saved: D:\mamaji\point_cloud_10_mesh.obj
# Mesh D:\mamaji\point_cloud_10_mesh.obj: Surface Area = 307561.8885631483
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 61
#      58 ply_file_path = os.path.join(input_ply_dir, ply_file)
#      59 output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_mesh.obj"))
# ---> 61 process_point_cloud(ply_file_path, output_mesh_file)
#      63 # Visualize the mesh
#      64 visualize_mesh(output_mesh_file)
#
# Cell In[1], line 20, in process_point_cloud(ply_file, output_mesh_file)
#      17 pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
#      19 # Surface reconstruction using the Ball-Pivoting Algorithm (BPA)
# ---> 20 distances = pcd.compute_nearest_neighbor_distance()
#      21 avg_dist = np.mean(distances)
#      22 radius = 3 * avg_dist
#
# KeyboardInterrupt:

# %%
import os
import open3d as o3d
import numpy as np
import pymeshlab
import matplotlib.pyplot as plt

def process_point_cloud(ply_file, output_mesh_file):
    # Load point cloud from PLY file
    pcd = o3d.io.read_point_cloud(ply_file)
    
    # Downsample the point cloud to reduce the number of points
    pcd = pcd.voxel_down_sample(voxel_size=0.02)
    
    # Remove noise from the point cloud using statistical outlier removal
    pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
    
    # Estimate normals for the downsampled and denoised point cloud
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Surface reconstruction using the Ball-Pivoting Algorithm (BPA)
    distances = pcd.compute_nearest_neighbor_distance()
    avg_dist = np.mean(distances)
    radius = 3 * avg_dist
    bpa_mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
        pcd, o3d.utility.DoubleVector([radius, radius * 2, radius * 3]))
    bpa_mesh.compute_vertex_normals()
    
    # Save the BPA mesh to an OBJ file
    o3d.io.write_triangle_mesh(output_mesh_file, bpa_mesh)
    
    print(f"Processed and saved: {output_mesh_file}")

# Function to visualize a mesh
def visualize_mesh(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()
    o3d.visualization.draw_geometries([mesh])

# Function to compute properties of the mesh
def compute_properties(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()

    # Surface area
    surface_area = mesh.get_surface_area()
    
    return surface_area

# Directory paths
input_ply_dir = r"D:\ply2"
output_mesh_dir = r"D:\mesh-2"

# Ensure the output directory exists
os.makedirs(output_mesh_dir, exist_ok=True)

# Process each point cloud file in the input directory
for ply_file in os.listdir(input_ply_dir):
    if ply_file.endswith(".ply"):
        ply_file_path = os.path.join(input_ply_dir, ply_file)
        output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_mesh.obj"))
        
        process_point_cloud(ply_file_path, output_mesh_file)
        
        # Visualize the mesh
        visualize_mesh(output_mesh_file)
        
        # Compute properties and handle non-watertight meshes
        surface_area = compute_properties(output_mesh_file)
        print(f"Mesh {output_mesh_file}: Surface Area = {surface_area}")

# %% [markdown]
# ## Delaunay Triangulation Method

# %%
import open3d as o3d
import numpy as np
from scipy.spatial import Delaunay
import matplotlib.pyplot as plt

def process_point_cloud_delaunay(ply_file, output_mesh_file):
    # Load point cloud from PLY file
    pcd = o3d.io.read_point_cloud(ply_file)
    
    # Downsample the point cloud to reduce the number of points
    pcd = pcd.voxel_down_sample(voxel_size=0.02)
    
    # Remove noise from the point cloud using statistical outlier removal
    pcd, ind = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=2.0)
    
    # Estimate normals for the downsampled and denoised point cloud
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Convert point cloud to numpy array
    points = np.asarray(pcd.points)
    
    # Project points to 2D plane (e.g., XY plane)
    points_2d = points[:, :2]
    
    # Perform Delaunay triangulation
    delaunay = Delaunay(points_2d)
    
    # Create triangles from the Delaunay simplices
    triangles = delaunay.simplices
    
    # Create Open3D triangle mesh
    mesh = o3d.geometry.TriangleMesh()
    mesh.vertices = o3d.utility.Vector3dVector(points)
    mesh.triangles = o3d.utility.Vector3iVector(triangles)
    
    # Compute vertex normals
    mesh.compute_vertex_normals()
    
    # Save the mesh to an OBJ file
    o3d.io.write_triangle_mesh(output_mesh_file, mesh)
    
    print(f"Processed and saved: {output_mesh_file}")

# Function to visualize a mesh
def visualize_mesh(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()
    o3d.visualization.draw_geometries([mesh])

# Function to compute properties of the mesh
def compute_properties(mesh_file):
    mesh = o3d.io.read_triangle_mesh(mesh_file)
    mesh.compute_vertex_normals()

    # Surface area
    surface_area = mesh.get_surface_area()

    return surface_area

# Directory paths
input_ply_dir = r"D:\ply3"
output_mesh_dir = r"D:\delaunay-mesh"

# Ensure the output directory exists
os.makedirs(output_mesh_dir, exist_ok=True)

# Process each point cloud file in the input directory
for ply_file in os.listdir(input_ply_dir):
    if ply_file.endswith(".ply"):
        ply_file_path = os.path.join(input_ply_dir, ply_file)
        output_mesh_file = os.path.join(output_mesh_dir, ply_file.replace(".ply", "_delaunay_mesh.obj"))
        
        process_point_cloud_delaunay(ply_file_path, output_mesh_file)
        
        # Visualize the mesh
        visualize_mesh(output_mesh_file)
        
        # Compute properties
        surface_area = compute_properties(output_mesh_file)
        print(f"Mesh {output_mesh_file}: Surface Area = {surface_area}")
