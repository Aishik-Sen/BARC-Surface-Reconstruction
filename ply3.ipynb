# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
mat_file_path = r"C:\Users\ADMIN\Desktop\NB-DAI\nyu_depth_v2_labeled.mat"

# %%
def save_point_cloud_to_ply(depth, filename):
    # Get the shape of the depth map
    height, width = depth.shape
    
    # Create a meshgrid of (x, y) coordinates
    x, y = np.meshgrid(np.arange(width), np.arange(height))
    
    # Flatten the arrays to create a list of points
    x = -1  * x.flatten()
    y = y.flatten()
    z = depth.flatten()
    z = 8 * z
    z = z * -1
    # Combine x, y, z coordinates into a single array
    points = np.vstack((x, y, z)).T
    depth =255- depths[index]
    
    # Save the point cloud to a PLY file
    with open(filename, 'w') as f:
        # Write the header
        f.write("ply\n")
        f.write("format ascii 1.0\n")
        f.write(f"element vertex {len(points)}\n")
        f.write("property float x\n")
        f.write("property float y\n")
        f.write("property float z\n")
        f.write("end_header\n")
        
        # Write the points
        for point in points:
            f.write(f"{point[0]} {point[1]} {point[2]}\n")

# %%
import os
output = r"D:\ply_final\three"
try:
    with h5py.File(mat_file_path, 'r') as mat_file:
        for index in range(1000,1450):
            # Save the point cloud to a PLY file
            ply_filename = os.path.join(output, f"point_cloud_{index + 1}.ply")
            depths = np.array(mat_file['depths'])
            save_point_cloud_to_ply(depths[index], ply_filename)
            print(f"Saved point cloud for image {index + 1} to {ply_filename}")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Saved point cloud for image 1001 to D:\ply_final\three\point_cloud_1001.ply
# Saved point cloud for image 1002 to D:\ply_final\three\point_cloud_1002.ply
# Saved point cloud for image 1003 to D:\ply_final\three\point_cloud_1003.ply
# Saved point cloud for image 1004 to D:\ply_final\three\point_cloud_1004.ply
# Saved point cloud for image 1005 to D:\ply_final\three\point_cloud_1005.ply
# Saved point cloud for image 1006 to D:\ply_final\three\point_cloud_1006.ply
# Saved point cloud for image 1007 to D:\ply_final\three\point_cloud_1007.ply
# Saved point cloud for image 1008 to D:\ply_final\three\point_cloud_1008.ply
# Saved point cloud for image 1009 to D:\ply_final\three\point_cloud_1009.ply
# Saved point cloud for image 1010 to D:\ply_final\three\point_cloud_1010.ply
# Saved point cloud for image 1011 to D:\ply_final\three\point_cloud_1011.ply
# Saved point cloud for image 1012 to D:\ply_final\three\point_cloud_1012.ply
# Saved point cloud for image 1013 to D:\ply_final\three\point_cloud_1013.ply
# Saved point cloud for image 1014 to D:\ply_final\three\point_cloud_1014.ply
# Saved point cloud for image 1015 to D:\ply_final\three\point_cloud_1015.ply
# Saved point cloud for image 1016 to D:\ply_final\three\point_cloud_1016.ply
# Saved point cloud for image 1017 to D:\ply_final\three\point_cloud_1017.ply
# Saved point cloud for image 1018 to D:\ply_final\three\point_cloud_1018.ply
# Saved point cloud for image 1019 to D:\ply_final\three\point_cloud_1019.ply
# Saved point cloud for image 1020 to D:\ply_final\three\point_cloud_1020.ply
# Saved point cloud for image 1021 to D:\ply_final\three\point_cloud_1021.ply
# Saved point cloud for image 1022 to D:\ply_final\three\point_cloud_1022.ply
# Saved point cloud for image 1023 to D:\ply_final\three\point_cloud_1023.ply
# Saved point cloud for image 1024 to D:\ply_final\three\point_cloud_1024.ply
# Saved point cloud for image 1025 to D:\ply_final\three\point_cloud_1025.ply
# Saved point cloud for image 1026 to D:\ply_final\three\point_cloud_1026.ply
# Saved point cloud for image 1027 to D:\ply_final\three\point_cloud_1027.ply
# Saved point cloud for image 1028 to D:\ply_final\three\point_cloud_1028.ply
# Saved point cloud for image 1029 to D:\ply_final\three\point_cloud_1029.ply
# Saved point cloud for image 1030 to D:\ply_final\three\point_cloud_1030.ply
# Saved point cloud for image 1031 to D:\ply_final\three\point_cloud_1031.ply
# Saved point cloud for image 1032 to D:\ply_final\three\point_cloud_1032.ply
# Saved point cloud for image 1033 to D:\ply_final\three\point_cloud_1033.ply
# Saved point cloud for image 1034 to D:\ply_final\three\point_cloud_1034.ply
# Saved point cloud for image 1035 to D:\ply_final\three\point_cloud_1035.ply
# Saved point cloud for image 1036 to D:\ply_final\three\point_cloud_1036.ply
# Saved point cloud for image 1037 to D:\ply_final\three\point_cloud_1037.ply
# Saved point cloud for image 1038 to D:\ply_final\three\point_cloud_1038.ply
# Saved point cloud for image 1039 to D:\ply_final\three\point_cloud_1039.ply
# Saved point cloud for image 1040 to D:\ply_final\three\point_cloud_1040.ply
# Saved point cloud for image 1041 to D:\ply_final\three\point_cloud_1041.ply
# Saved point cloud for image 1042 to D:\ply_final\three\point_cloud_1042.ply
# Saved point cloud for image 1043 to D:\ply_final\three\point_cloud_1043.ply
# Saved point cloud for image 1044 to D:\ply_final\three\point_cloud_1044.ply
# Saved point cloud for image 1045 to D:\ply_final\three\point_cloud_1045.ply
# Saved point cloud for image 1046 to D:\ply_final\three\point_cloud_1046.ply
# Saved point cloud for image 1047 to D:\ply_final\three\point_cloud_1047.ply
# Saved point cloud for image 1048 to D:\ply_final\three\point_cloud_1048.ply
# Saved point cloud for image 1049 to D:\ply_final\three\point_cloud_1049.ply
# Saved point cloud for image 1050 to D:\ply_final\three\point_cloud_1050.ply
# Saved point cloud for image 1051 to D:\ply_final\three\point_cloud_1051.ply
# Saved point cloud for image 1052 to D:\ply_final\three\point_cloud_1052.ply
# Saved point cloud for image 1053 to D:\ply_final\three\point_cloud_1053.ply
# Saved point cloud for image 1054 to D:\ply_final\three\point_cloud_1054.ply
# Saved point cloud for image 1055 to D:\ply_final\three\point_cloud_1055.ply
# Saved point cloud for image 1056 to D:\ply_final\three\point_cloud_1056.ply
# Saved point cloud for image 1057 to D:\ply_final\three\point_cloud_1057.ply
# Saved point cloud for image 1058 to D:\ply_final\three\point_cloud_1058.ply
# Saved point cloud for image 1059 to D:\ply_final\three\point_cloud_1059.ply
# Saved point cloud for image 1060 to D:\ply_final\three\point_cloud_1060.ply
# Saved point cloud for image 1061 to D:\ply_final\three\point_cloud_1061.ply
# Saved point cloud for image 1062 to D:\ply_final\three\point_cloud_1062.ply
# Saved point cloud for image 1063 to D:\ply_final\three\point_cloud_1063.ply
# Saved point cloud for image 1064 to D:\ply_final\three\point_cloud_1064.ply
# Saved point cloud for image 1065 to D:\ply_final\three\point_cloud_1065.ply
# Saved point cloud for image 1066 to D:\ply_final\three\point_cloud_1066.ply
# Saved point cloud for image 1067 to D:\ply_final\three\point_cloud_1067.ply
# Saved point cloud for image 1068 to D:\ply_final\three\point_cloud_1068.ply
# Saved point cloud for image 1069 to D:\ply_final\three\point_cloud_1069.ply
# Saved point cloud for image 1070 to D:\ply_final\three\point_cloud_1070.ply
# Saved point cloud for image 1071 to D:\ply_final\three\point_cloud_1071.ply
# Saved point cloud for image 1072 to D:\ply_final\three\point_cloud_1072.ply
# Saved point cloud for image 1073 to D:\ply_final\three\point_cloud_1073.ply
# Saved point cloud for image 1074 to D:\ply_final\three\point_cloud_1074.ply
# Saved point cloud for image 1075 to D:\ply_final\three\point_cloud_1075.ply
# Saved point cloud for image 1076 to D:\ply_final\three\point_cloud_1076.ply
# Saved point cloud for image 1077 to D:\ply_final\three\point_cloud_1077.ply
# Saved point cloud for image 1078 to D:\ply_final\three\point_cloud_1078.ply
# Saved point cloud for image 1079 to D:\ply_final\three\point_cloud_1079.ply
# Saved point cloud for image 1080 to D:\ply_final\three\point_cloud_1080.ply
# Saved point cloud for image 1081 to D:\ply_final\three\point_cloud_1081.ply
# Saved point cloud for image 1082 to D:\ply_final\three\point_cloud_1082.ply
# Saved point cloud for image 1083 to D:\ply_final\three\point_cloud_1083.ply
# Saved point cloud for image 1084 to D:\ply_final\three\point_cloud_1084.ply
# Saved point cloud for image 1085 to D:\ply_final\three\point_cloud_1085.ply
# Saved point cloud for image 1086 to D:\ply_final\three\point_cloud_1086.ply
# Saved point cloud for image 1087 to D:\ply_final\three\point_cloud_1087.ply
# Saved point cloud for image 1088 to D:\ply_final\three\point_cloud_1088.ply
# Saved point cloud for image 1089 to D:\ply_final\three\point_cloud_1089.ply
# Saved point cloud for image 1090 to D:\ply_final\three\point_cloud_1090.ply
# Saved point cloud for image 1091 to D:\ply_final\three\point_cloud_1091.ply
# Saved point cloud for image 1092 to D:\ply_final\three\point_cloud_1092.ply
# Saved point cloud for image 1093 to D:\ply_final\three\point_cloud_1093.ply
# Saved point cloud for image 1094 to D:\ply_final\three\point_cloud_1094.ply
# Saved point cloud for image 1095 to D:\ply_final\three\point_cloud_1095.ply
# Saved point cloud for image 1096 to D:\ply_final\three\point_cloud_1096.ply
# Saved point cloud for image 1097 to D:\ply_final\three\point_cloud_1097.ply
# Saved point cloud for image 1098 to D:\ply_final\three\point_cloud_1098.ply
# Saved point cloud for image 1099 to D:\ply_final\three\point_cloud_1099.ply
# Saved point cloud for image 1100 to D:\ply_final\three\point_cloud_1100.ply
# Saved point cloud for image 1101 to D:\ply_final\three\point_cloud_1101.ply
# Saved point cloud for image 1102 to D:\ply_final\three\point_cloud_1102.ply
# Saved point cloud for image 1103 to D:\ply_final\three\point_cloud_1103.ply
# Saved point cloud for image 1104 to D:\ply_final\three\point_cloud_1104.ply
# Saved point cloud for image 1105 to D:\ply_final\three\point_cloud_1105.ply
# Saved point cloud for image 1106 to D:\ply_final\three\point_cloud_1106.ply
# Saved point cloud for image 1107 to D:\ply_final\three\point_cloud_1107.ply
# Saved point cloud for image 1108 to D:\ply_final\three\point_cloud_1108.ply
# Saved point cloud for image 1109 to D:\ply_final\three\point_cloud_1109.ply
# Saved point cloud for image 1110 to D:\ply_final\three\point_cloud_1110.ply
# Saved point cloud for image 1111 to D:\ply_final\three\point_cloud_1111.ply
# Saved point cloud for image 1112 to D:\ply_final\three\point_cloud_1112.ply
# Saved point cloud for image 1113 to D:\ply_final\three\point_cloud_1113.ply
# Saved point cloud for image 1114 to D:\ply_final\three\point_cloud_1114.ply
# Saved point cloud for image 1115 to D:\ply_final\three\point_cloud_1115.ply
# Saved point cloud for image 1116 to D:\ply_final\three\point_cloud_1116.ply
# Saved point cloud for image 1117 to D:\ply_final\three\point_cloud_1117.ply
# Saved point cloud for image 1118 to D:\ply_final\three\point_cloud_1118.ply
# Saved point cloud for image 1119 to D:\ply_final\three\point_cloud_1119.ply
# Saved point cloud for image 1120 to D:\ply_final\three\point_cloud_1120.ply
# Saved point cloud for image 1121 to D:\ply_final\three\point_cloud_1121.ply
# Saved point cloud for image 1122 to D:\ply_final\three\point_cloud_1122.ply
# Saved point cloud for image 1123 to D:\ply_final\three\point_cloud_1123.ply
# Saved point cloud for image 1124 to D:\ply_final\three\point_cloud_1124.ply
# Saved point cloud for image 1125 to D:\ply_final\three\point_cloud_1125.ply
# Saved point cloud for image 1126 to D:\ply_final\three\point_cloud_1126.ply
# Saved point cloud for image 1127 to D:\ply_final\three\point_cloud_1127.ply
# Saved point cloud for image 1128 to D:\ply_final\three\point_cloud_1128.ply
# Saved point cloud for image 1129 to D:\ply_final\three\point_cloud_1129.ply
# Saved point cloud for image 1130 to D:\ply_final\three\point_cloud_1130.ply
# Saved point cloud for image 1131 to D:\ply_final\three\point_cloud_1131.ply
# Saved point cloud for image 1132 to D:\ply_final\three\point_cloud_1132.ply
# Saved point cloud for image 1133 to D:\ply_final\three\point_cloud_1133.ply
# Saved point cloud for image 1134 to D:\ply_final\three\point_cloud_1134.ply
# Saved point cloud for image 1135 to D:\ply_final\three\point_cloud_1135.ply
# Saved point cloud for image 1136 to D:\ply_final\three\point_cloud_1136.ply
# Saved point cloud for image 1137 to D:\ply_final\three\point_cloud_1137.ply
# Saved point cloud for image 1138 to D:\ply_final\three\point_cloud_1138.ply
# Saved point cloud for image 1139 to D:\ply_final\three\point_cloud_1139.ply
# Saved point cloud for image 1140 to D:\ply_final\three\point_cloud_1140.ply
# Saved point cloud for image 1141 to D:\ply_final\three\point_cloud_1141.ply
# Saved point cloud for image 1142 to D:\ply_final\three\point_cloud_1142.ply
# Saved point cloud for image 1143 to D:\ply_final\three\point_cloud_1143.ply
# Saved point cloud for image 1144 to D:\ply_final\three\point_cloud_1144.ply
# Saved point cloud for image 1145 to D:\ply_final\three\point_cloud_1145.ply
# Saved point cloud for image 1146 to D:\ply_final\three\point_cloud_1146.ply
# Saved point cloud for image 1147 to D:\ply_final\three\point_cloud_1147.ply
# Saved point cloud for image 1148 to D:\ply_final\three\point_cloud_1148.ply
# Saved point cloud for image 1149 to D:\ply_final\three\point_cloud_1149.ply
# Saved point cloud for image 1150 to D:\ply_final\three\point_cloud_1150.ply
# Saved point cloud for image 1151 to D:\ply_final\three\point_cloud_1151.ply
# Saved point cloud for image 1152 to D:\ply_final\three\point_cloud_1152.ply
# Saved point cloud for image 1153 to D:\ply_final\three\point_cloud_1153.ply
# Saved point cloud for image 1154 to D:\ply_final\three\point_cloud_1154.ply
# Saved point cloud for image 1155 to D:\ply_final\three\point_cloud_1155.ply
# Saved point cloud for image 1156 to D:\ply_final\three\point_cloud_1156.ply
# Saved point cloud for image 1157 to D:\ply_final\three\point_cloud_1157.ply
# Saved point cloud for image 1158 to D:\ply_final\three\point_cloud_1158.ply
# Saved point cloud for image 1159 to D:\ply_final\three\point_cloud_1159.ply
# Saved point cloud for image 1160 to D:\ply_final\three\point_cloud_1160.ply
# Saved point cloud for image 1161 to D:\ply_final\three\point_cloud_1161.ply
# Saved point cloud for image 1162 to D:\ply_final\three\point_cloud_1162.ply
# Saved point cloud for image 1163 to D:\ply_final\three\point_cloud_1163.ply
# Saved point cloud for image 1164 to D:\ply_final\three\point_cloud_1164.ply
# Saved point cloud for image 1165 to D:\ply_final\three\point_cloud_1165.ply
# Saved point cloud for image 1166 to D:\ply_final\three\point_cloud_1166.ply
# Saved point cloud for image 1167 to D:\ply_final\three\point_cloud_1167.ply
# Saved point cloud for image 1168 to D:\ply_final\three\point_cloud_1168.ply
# Saved point cloud for image 1169 to D:\ply_final\three\point_cloud_1169.ply
# Saved point cloud for image 1170 to D:\ply_final\three\point_cloud_1170.ply
# Saved point cloud for image 1171 to D:\ply_final\three\point_cloud_1171.ply
# Saved point cloud for image 1172 to D:\ply_final\three\point_cloud_1172.ply
# Saved point cloud for image 1173 to D:\ply_final\three\point_cloud_1173.ply
# Saved point cloud for image 1174 to D:\ply_final\three\point_cloud_1174.ply
# Saved point cloud for image 1175 to D:\ply_final\three\point_cloud_1175.ply
# Saved point cloud for image 1176 to D:\ply_final\three\point_cloud_1176.ply
# Saved point cloud for image 1177 to D:\ply_final\three\point_cloud_1177.ply
# Saved point cloud for image 1178 to D:\ply_final\three\point_cloud_1178.ply
# Saved point cloud for image 1179 to D:\ply_final\three\point_cloud_1179.ply
# Saved point cloud for image 1180 to D:\ply_final\three\point_cloud_1180.ply
# Saved point cloud for image 1181 to D:\ply_final\three\point_cloud_1181.ply
# Saved point cloud for image 1182 to D:\ply_final\three\point_cloud_1182.ply
# Saved point cloud for image 1183 to D:\ply_final\three\point_cloud_1183.ply
# Saved point cloud for image 1184 to D:\ply_final\three\point_cloud_1184.ply
# Saved point cloud for image 1185 to D:\ply_final\three\point_cloud_1185.ply
# Saved point cloud for image 1186 to D:\ply_final\three\point_cloud_1186.ply
# Saved point cloud for image 1187 to D:\ply_final\three\point_cloud_1187.ply
# Saved point cloud for image 1188 to D:\ply_final\three\point_cloud_1188.ply
# Saved point cloud for image 1189 to D:\ply_final\three\point_cloud_1189.ply
# Saved point cloud for image 1190 to D:\ply_final\three\point_cloud_1190.ply
# Saved point cloud for image 1191 to D:\ply_final\three\point_cloud_1191.ply
# Saved point cloud for image 1192 to D:\ply_final\three\point_cloud_1192.ply
# Saved point cloud for image 1193 to D:\ply_final\three\point_cloud_1193.ply
# Saved point cloud for image 1194 to D:\ply_final\three\point_cloud_1194.ply
# Saved point cloud for image 1195 to D:\ply_final\three\point_cloud_1195.ply
# Saved point cloud for image 1196 to D:\ply_final\three\point_cloud_1196.ply
# Saved point cloud for image 1197 to D:\ply_final\three\point_cloud_1197.ply
# Saved point cloud for image 1198 to D:\ply_final\three\point_cloud_1198.ply
# Saved point cloud for image 1199 to D:\ply_final\three\point_cloud_1199.ply
# Saved point cloud for image 1200 to D:\ply_final\three\point_cloud_1200.ply
# Saved point cloud for image 1201 to D:\ply_final\three\point_cloud_1201.ply
# Saved point cloud for image 1202 to D:\ply_final\three\point_cloud_1202.ply
# Saved point cloud for image 1203 to D:\ply_final\three\point_cloud_1203.ply
# Saved point cloud for image 1204 to D:\ply_final\three\point_cloud_1204.ply
# Saved point cloud for image 1205 to D:\ply_final\three\point_cloud_1205.ply
# Saved point cloud for image 1206 to D:\ply_final\three\point_cloud_1206.ply
# Saved point cloud for image 1207 to D:\ply_final\three\point_cloud_1207.ply
# Saved point cloud for image 1208 to D:\ply_final\three\point_cloud_1208.ply
# Saved point cloud for image 1209 to D:\ply_final\three\point_cloud_1209.ply
# Saved point cloud for image 1210 to D:\ply_final\three\point_cloud_1210.ply
# Saved point cloud for image 1211 to D:\ply_final\three\point_cloud_1211.ply
# Saved point cloud for image 1212 to D:\ply_final\three\point_cloud_1212.ply
# Saved point cloud for image 1213 to D:\ply_final\three\point_cloud_1213.ply
# Saved point cloud for image 1214 to D:\ply_final\three\point_cloud_1214.ply
# Saved point cloud for image 1215 to D:\ply_final\three\point_cloud_1215.ply
# Saved point cloud for image 1216 to D:\ply_final\three\point_cloud_1216.ply
# Saved point cloud for image 1217 to D:\ply_final\three\point_cloud_1217.ply
# Saved point cloud for image 1218 to D:\ply_final\three\point_cloud_1218.ply
# Saved point cloud for image 1219 to D:\ply_final\three\point_cloud_1219.ply
# Saved point cloud for image 1220 to D:\ply_final\three\point_cloud_1220.ply
# Saved point cloud for image 1221 to D:\ply_final\three\point_cloud_1221.ply
# Saved point cloud for image 1222 to D:\ply_final\three\point_cloud_1222.ply
# Saved point cloud for image 1223 to D:\ply_final\three\point_cloud_1223.ply
# Saved point cloud for image 1224 to D:\ply_final\three\point_cloud_1224.ply
# Saved point cloud for image 1225 to D:\ply_final\three\point_cloud_1225.ply
# Saved point cloud for image 1226 to D:\ply_final\three\point_cloud_1226.ply
# Saved point cloud for image 1227 to D:\ply_final\three\point_cloud_1227.ply
# Saved point cloud for image 1228 to D:\ply_final\three\point_cloud_1228.ply
# Saved point cloud for image 1229 to D:\ply_final\three\point_cloud_1229.ply
# Saved point cloud for image 1230 to D:\ply_final\three\point_cloud_1230.ply
# Saved point cloud for image 1231 to D:\ply_final\three\point_cloud_1231.ply
# Saved point cloud for image 1232 to D:\ply_final\three\point_cloud_1232.ply
# Saved point cloud for image 1233 to D:\ply_final\three\point_cloud_1233.ply
# Saved point cloud for image 1234 to D:\ply_final\three\point_cloud_1234.ply
# Saved point cloud for image 1235 to D:\ply_final\three\point_cloud_1235.ply
# Saved point cloud for image 1236 to D:\ply_final\three\point_cloud_1236.ply
# Saved point cloud for image 1237 to D:\ply_final\three\point_cloud_1237.ply
# Saved point cloud for image 1238 to D:\ply_final\three\point_cloud_1238.ply
# Saved point cloud for image 1239 to D:\ply_final\three\point_cloud_1239.ply
# Saved point cloud for image 1240 to D:\ply_final\three\point_cloud_1240.ply
# Saved point cloud for image 1241 to D:\ply_final\three\point_cloud_1241.ply
# Saved point cloud for image 1242 to D:\ply_final\three\point_cloud_1242.ply
# Saved point cloud for image 1243 to D:\ply_final\three\point_cloud_1243.ply
# Saved point cloud for image 1244 to D:\ply_final\three\point_cloud_1244.ply
# Saved point cloud for image 1245 to D:\ply_final\three\point_cloud_1245.ply
# Saved point cloud for image 1246 to D:\ply_final\three\point_cloud_1246.ply
# Saved point cloud for image 1247 to D:\ply_final\three\point_cloud_1247.ply
# Saved point cloud for image 1248 to D:\ply_final\three\point_cloud_1248.ply
# Saved point cloud for image 1249 to D:\ply_final\three\point_cloud_1249.ply
# Saved point cloud for image 1250 to D:\ply_final\three\point_cloud_1250.ply
# Saved point cloud for image 1251 to D:\ply_final\three\point_cloud_1251.ply
# Saved point cloud for image 1252 to D:\ply_final\three\point_cloud_1252.ply
# Saved point cloud for image 1253 to D:\ply_final\three\point_cloud_1253.ply
# Saved point cloud for image 1254 to D:\ply_final\three\point_cloud_1254.ply
# Saved point cloud for image 1255 to D:\ply_final\three\point_cloud_1255.ply
# Saved point cloud for image 1256 to D:\ply_final\three\point_cloud_1256.ply
# Saved point cloud for image 1257 to D:\ply_final\three\point_cloud_1257.ply
# Saved point cloud for image 1258 to D:\ply_final\three\point_cloud_1258.ply
# Saved point cloud for image 1259 to D:\ply_final\three\point_cloud_1259.ply
# Saved point cloud for image 1260 to D:\ply_final\three\point_cloud_1260.ply
# Saved point cloud for image 1261 to D:\ply_final\three\point_cloud_1261.ply
# Saved point cloud for image 1262 to D:\ply_final\three\point_cloud_1262.ply
# Saved point cloud for image 1263 to D:\ply_final\three\point_cloud_1263.ply
# Saved point cloud for image 1264 to D:\ply_final\three\point_cloud_1264.ply
# Saved point cloud for image 1265 to D:\ply_final\three\point_cloud_1265.ply
# Saved point cloud for image 1266 to D:\ply_final\three\point_cloud_1266.ply
# Saved point cloud for image 1267 to D:\ply_final\three\point_cloud_1267.ply
# Saved point cloud for image 1268 to D:\ply_final\three\point_cloud_1268.ply
# Saved point cloud for image 1269 to D:\ply_final\three\point_cloud_1269.ply
# Saved point cloud for image 1270 to D:\ply_final\three\point_cloud_1270.ply
# Saved point cloud for image 1271 to D:\ply_final\three\point_cloud_1271.ply
# Saved point cloud for image 1272 to D:\ply_final\three\point_cloud_1272.ply
# Saved point cloud for image 1273 to D:\ply_final\three\point_cloud_1273.ply
# Saved point cloud for image 1274 to D:\ply_final\three\point_cloud_1274.ply
# Saved point cloud for image 1275 to D:\ply_final\three\point_cloud_1275.ply
# Saved point cloud for image 1276 to D:\ply_final\three\point_cloud_1276.ply
# Saved point cloud for image 1277 to D:\ply_final\three\point_cloud_1277.ply
# Saved point cloud for image 1278 to D:\ply_final\three\point_cloud_1278.ply
# Saved point cloud for image 1279 to D:\ply_final\three\point_cloud_1279.ply
# Saved point cloud for image 1280 to D:\ply_final\three\point_cloud_1280.ply
# Saved point cloud for image 1281 to D:\ply_final\three\point_cloud_1281.ply
# Saved point cloud for image 1282 to D:\ply_final\three\point_cloud_1282.ply
# Saved point cloud for image 1283 to D:\ply_final\three\point_cloud_1283.ply
# Saved point cloud for image 1284 to D:\ply_final\three\point_cloud_1284.ply
# Saved point cloud for image 1285 to D:\ply_final\three\point_cloud_1285.ply
# Saved point cloud for image 1286 to D:\ply_final\three\point_cloud_1286.ply
# Saved point cloud for image 1287 to D:\ply_final\three\point_cloud_1287.ply
# Saved point cloud for image 1288 to D:\ply_final\three\point_cloud_1288.ply
# Saved point cloud for image 1289 to D:\ply_final\three\point_cloud_1289.ply
# Saved point cloud for image 1290 to D:\ply_final\three\point_cloud_1290.ply
# Saved point cloud for image 1291 to D:\ply_final\three\point_cloud_1291.ply
# Saved point cloud for image 1292 to D:\ply_final\three\point_cloud_1292.ply
# Saved point cloud for image 1293 to D:\ply_final\three\point_cloud_1293.ply
# Saved point cloud for image 1294 to D:\ply_final\three\point_cloud_1294.ply
# Saved point cloud for image 1295 to D:\ply_final\three\point_cloud_1295.ply
# Saved point cloud for image 1296 to D:\ply_final\three\point_cloud_1296.ply
# Saved point cloud for image 1297 to D:\ply_final\three\point_cloud_1297.ply
# Saved point cloud for image 1298 to D:\ply_final\three\point_cloud_1298.ply
# Saved point cloud for image 1299 to D:\ply_final\three\point_cloud_1299.ply
# Saved point cloud for image 1300 to D:\ply_final\three\point_cloud_1300.ply
# Saved point cloud for image 1301 to D:\ply_final\three\point_cloud_1301.ply
# Saved point cloud for image 1302 to D:\ply_final\three\point_cloud_1302.ply
# Saved point cloud for image 1303 to D:\ply_final\three\point_cloud_1303.ply
# Saved point cloud for image 1304 to D:\ply_final\three\point_cloud_1304.ply
# Saved point cloud for image 1305 to D:\ply_final\three\point_cloud_1305.ply
# Saved point cloud for image 1306 to D:\ply_final\three\point_cloud_1306.ply
# Saved point cloud for image 1307 to D:\ply_final\three\point_cloud_1307.ply
# Saved point cloud for image 1308 to D:\ply_final\three\point_cloud_1308.ply
# Saved point cloud for image 1309 to D:\ply_final\three\point_cloud_1309.ply
# Saved point cloud for image 1310 to D:\ply_final\three\point_cloud_1310.ply
# Saved point cloud for image 1311 to D:\ply_final\three\point_cloud_1311.ply
# Saved point cloud for image 1312 to D:\ply_final\three\point_cloud_1312.ply
# Saved point cloud for image 1313 to D:\ply_final\three\point_cloud_1313.ply
# Saved point cloud for image 1314 to D:\ply_final\three\point_cloud_1314.ply
# Saved point cloud for image 1315 to D:\ply_final\three\point_cloud_1315.ply
# Saved point cloud for image 1316 to D:\ply_final\three\point_cloud_1316.ply
# Saved point cloud for image 1317 to D:\ply_final\three\point_cloud_1317.ply
# Saved point cloud for image 1318 to D:\ply_final\three\point_cloud_1318.ply
# Saved point cloud for image 1319 to D:\ply_final\three\point_cloud_1319.ply
# Saved point cloud for image 1320 to D:\ply_final\three\point_cloud_1320.ply
# Saved point cloud for image 1321 to D:\ply_final\three\point_cloud_1321.ply
# Saved point cloud for image 1322 to D:\ply_final\three\point_cloud_1322.ply
# Saved point cloud for image 1323 to D:\ply_final\three\point_cloud_1323.ply
# Saved point cloud for image 1324 to D:\ply_final\three\point_cloud_1324.ply
# Saved point cloud for image 1325 to D:\ply_final\three\point_cloud_1325.ply
# Saved point cloud for image 1326 to D:\ply_final\three\point_cloud_1326.ply
# Saved point cloud for image 1327 to D:\ply_final\three\point_cloud_1327.ply
# Saved point cloud for image 1328 to D:\ply_final\three\point_cloud_1328.ply
# Saved point cloud for image 1329 to D:\ply_final\three\point_cloud_1329.ply
# Saved point cloud for image 1330 to D:\ply_final\three\point_cloud_1330.ply
# Saved point cloud for image 1331 to D:\ply_final\three\point_cloud_1331.ply
# Saved point cloud for image 1332 to D:\ply_final\three\point_cloud_1332.ply
# Saved point cloud for image 1333 to D:\ply_final\three\point_cloud_1333.ply
# Saved point cloud for image 1334 to D:\ply_final\three\point_cloud_1334.ply
# Saved point cloud for image 1335 to D:\ply_final\three\point_cloud_1335.ply
# Saved point cloud for image 1336 to D:\ply_final\three\point_cloud_1336.ply
# Saved point cloud for image 1337 to D:\ply_final\three\point_cloud_1337.ply
# Saved point cloud for image 1338 to D:\ply_final\three\point_cloud_1338.ply
# Saved point cloud for image 1339 to D:\ply_final\three\point_cloud_1339.ply
# Saved point cloud for image 1340 to D:\ply_final\three\point_cloud_1340.ply
# Saved point cloud for image 1341 to D:\ply_final\three\point_cloud_1341.ply
# Saved point cloud for image 1342 to D:\ply_final\three\point_cloud_1342.ply
# Saved point cloud for image 1343 to D:\ply_final\three\point_cloud_1343.ply
# Saved point cloud for image 1344 to D:\ply_final\three\point_cloud_1344.ply
# Saved point cloud for image 1345 to D:\ply_final\three\point_cloud_1345.ply
# Saved point cloud for image 1346 to D:\ply_final\three\point_cloud_1346.ply
# Saved point cloud for image 1347 to D:\ply_final\three\point_cloud_1347.ply
# Saved point cloud for image 1348 to D:\ply_final\three\point_cloud_1348.ply
# Saved point cloud for image 1349 to D:\ply_final\three\point_cloud_1349.ply
# Saved point cloud for image 1350 to D:\ply_final\three\point_cloud_1350.ply
# Saved point cloud for image 1351 to D:\ply_final\three\point_cloud_1351.ply
# Saved point cloud for image 1352 to D:\ply_final\three\point_cloud_1352.ply
# Saved point cloud for image 1353 to D:\ply_final\three\point_cloud_1353.ply
# Saved point cloud for image 1354 to D:\ply_final\three\point_cloud_1354.ply
# Saved point cloud for image 1355 to D:\ply_final\three\point_cloud_1355.ply
# Saved point cloud for image 1356 to D:\ply_final\three\point_cloud_1356.ply
# Saved point cloud for image 1357 to D:\ply_final\three\point_cloud_1357.ply
# Saved point cloud for image 1358 to D:\ply_final\three\point_cloud_1358.ply
# Saved point cloud for image 1359 to D:\ply_final\three\point_cloud_1359.ply
# Saved point cloud for image 1360 to D:\ply_final\three\point_cloud_1360.ply
# Saved point cloud for image 1361 to D:\ply_final\three\point_cloud_1361.ply
# Saved point cloud for image 1362 to D:\ply_final\three\point_cloud_1362.ply
# Saved point cloud for image 1363 to D:\ply_final\three\point_cloud_1363.ply
# Saved point cloud for image 1364 to D:\ply_final\three\point_cloud_1364.ply
# Saved point cloud for image 1365 to D:\ply_final\three\point_cloud_1365.ply
# Saved point cloud for image 1366 to D:\ply_final\three\point_cloud_1366.ply
# Saved point cloud for image 1367 to D:\ply_final\three\point_cloud_1367.ply
# Saved point cloud for image 1368 to D:\ply_final\three\point_cloud_1368.ply
# Saved point cloud for image 1369 to D:\ply_final\three\point_cloud_1369.ply
# Saved point cloud for image 1370 to D:\ply_final\three\point_cloud_1370.ply
# Saved point cloud for image 1371 to D:\ply_final\three\point_cloud_1371.ply
# Saved point cloud for image 1372 to D:\ply_final\three\point_cloud_1372.ply
# Saved point cloud for image 1373 to D:\ply_final\three\point_cloud_1373.ply
# Saved point cloud for image 1374 to D:\ply_final\three\point_cloud_1374.ply
# Saved point cloud for image 1375 to D:\ply_final\three\point_cloud_1375.ply
# Saved point cloud for image 1376 to D:\ply_final\three\point_cloud_1376.ply
# Saved point cloud for image 1377 to D:\ply_final\three\point_cloud_1377.ply
# Saved point cloud for image 1378 to D:\ply_final\three\point_cloud_1378.ply
# Saved point cloud for image 1379 to D:\ply_final\three\point_cloud_1379.ply
# Saved point cloud for image 1380 to D:\ply_final\three\point_cloud_1380.ply
# Saved point cloud for image 1381 to D:\ply_final\three\point_cloud_1381.ply
# Saved point cloud for image 1382 to D:\ply_final\three\point_cloud_1382.ply
# Saved point cloud for image 1383 to D:\ply_final\three\point_cloud_1383.ply
# Saved point cloud for image 1384 to D:\ply_final\three\point_cloud_1384.ply
# Saved point cloud for image 1385 to D:\ply_final\three\point_cloud_1385.ply
# Saved point cloud for image 1386 to D:\ply_final\three\point_cloud_1386.ply
# Saved point cloud for image 1387 to D:\ply_final\three\point_cloud_1387.ply
# Saved point cloud for image 1388 to D:\ply_final\three\point_cloud_1388.ply
# Saved point cloud for image 1389 to D:\ply_final\three\point_cloud_1389.ply
# Saved point cloud for image 1390 to D:\ply_final\three\point_cloud_1390.ply
# Saved point cloud for image 1391 to D:\ply_final\three\point_cloud_1391.ply
# Saved point cloud for image 1392 to D:\ply_final\three\point_cloud_1392.ply
# Saved point cloud for image 1393 to D:\ply_final\three\point_cloud_1393.ply
# Saved point cloud for image 1394 to D:\ply_final\three\point_cloud_1394.ply
# Saved point cloud for image 1395 to D:\ply_final\three\point_cloud_1395.ply
# Saved point cloud for image 1396 to D:\ply_final\three\point_cloud_1396.ply
# Saved point cloud for image 1397 to D:\ply_final\three\point_cloud_1397.ply
# Saved point cloud for image 1398 to D:\ply_final\three\point_cloud_1398.ply
# Saved point cloud for image 1399 to D:\ply_final\three\point_cloud_1399.ply
# Saved point cloud for image 1400 to D:\ply_final\three\point_cloud_1400.ply
# Saved point cloud for image 1401 to D:\ply_final\three\point_cloud_1401.ply
# Saved point cloud for image 1402 to D:\ply_final\three\point_cloud_1402.ply
# Saved point cloud for image 1403 to D:\ply_final\three\point_cloud_1403.ply
# Saved point cloud for image 1404 to D:\ply_final\three\point_cloud_1404.ply
# Saved point cloud for image 1405 to D:\ply_final\three\point_cloud_1405.ply
# Saved point cloud for image 1406 to D:\ply_final\three\point_cloud_1406.ply
# Saved point cloud for image 1407 to D:\ply_final\three\point_cloud_1407.ply
# Saved point cloud for image 1408 to D:\ply_final\three\point_cloud_1408.ply
# Saved point cloud for image 1409 to D:\ply_final\three\point_cloud_1409.ply
# Saved point cloud for image 1410 to D:\ply_final\three\point_cloud_1410.ply
# Saved point cloud for image 1411 to D:\ply_final\three\point_cloud_1411.ply
# Saved point cloud for image 1412 to D:\ply_final\three\point_cloud_1412.ply
# Saved point cloud for image 1413 to D:\ply_final\three\point_cloud_1413.ply
# Saved point cloud for image 1414 to D:\ply_final\three\point_cloud_1414.ply
# Saved point cloud for image 1415 to D:\ply_final\three\point_cloud_1415.ply
# Saved point cloud for image 1416 to D:\ply_final\three\point_cloud_1416.ply
# Saved point cloud for image 1417 to D:\ply_final\three\point_cloud_1417.ply
# Saved point cloud for image 1418 to D:\ply_final\three\point_cloud_1418.ply
# Saved point cloud for image 1419 to D:\ply_final\three\point_cloud_1419.ply
# Saved point cloud for image 1420 to D:\ply_final\three\point_cloud_1420.ply
# Saved point cloud for image 1421 to D:\ply_final\three\point_cloud_1421.ply
# Saved point cloud for image 1422 to D:\ply_final\three\point_cloud_1422.ply
# Saved point cloud for image 1423 to D:\ply_final\three\point_cloud_1423.ply
# Saved point cloud for image 1424 to D:\ply_final\three\point_cloud_1424.ply
# Saved point cloud for image 1425 to D:\ply_final\three\point_cloud_1425.ply
# Saved point cloud for image 1426 to D:\ply_final\three\point_cloud_1426.ply
# Saved point cloud for image 1427 to D:\ply_final\three\point_cloud_1427.ply
# Saved point cloud for image 1428 to D:\ply_final\three\point_cloud_1428.ply
# Saved point cloud for image 1429 to D:\ply_final\three\point_cloud_1429.ply
# Saved point cloud for image 1430 to D:\ply_final\three\point_cloud_1430.ply
# Saved point cloud for image 1431 to D:\ply_final\three\point_cloud_1431.ply
# Saved point cloud for image 1432 to D:\ply_final\three\point_cloud_1432.ply
# Saved point cloud for image 1433 to D:\ply_final\three\point_cloud_1433.ply
# Saved point cloud for image 1434 to D:\ply_final\three\point_cloud_1434.ply
# Saved point cloud for image 1435 to D:\ply_final\three\point_cloud_1435.ply
# Saved point cloud for image 1436 to D:\ply_final\three\point_cloud_1436.ply
# Saved point cloud for image 1437 to D:\ply_final\three\point_cloud_1437.ply
# Saved point cloud for image 1438 to D:\ply_final\three\point_cloud_1438.ply
# Saved point cloud for image 1439 to D:\ply_final\three\point_cloud_1439.ply
# Saved point cloud for image 1440 to D:\ply_final\three\point_cloud_1440.ply
# Saved point cloud for image 1441 to D:\ply_final\three\point_cloud_1441.ply
# Saved point cloud for image 1442 to D:\ply_final\three\point_cloud_1442.ply
# Saved point cloud for image 1443 to D:\ply_final\three\point_cloud_1443.ply
# Saved point cloud for image 1444 to D:\ply_final\three\point_cloud_1444.ply
# Saved point cloud for image 1445 to D:\ply_final\three\point_cloud_1445.ply
# Saved point cloud for image 1446 to D:\ply_final\three\point_cloud_1446.ply
# Saved point cloud for image 1447 to D:\ply_final\three\point_cloud_1447.ply
# Saved point cloud for image 1448 to D:\ply_final\three\point_cloud_1448.ply
# Saved point cloud for image 1449 to D:\ply_final\three\point_cloud_1449.ply
# An error occurred: index 1449 is out of bounds for axis 0 with size 1449
